# %% [markdown]
# [Softmax function quiz](https://classroom.udacity.com/courses/ud730/lessons/6370362152/concepts/63815621490923#) from udacity Deep Learning course

# %%
scores = [3.0, 1.0, 0.2]

import numpy as np


# def softmax(x):
#     """Compute softmax values for each sets of scores in x.""# #     pass  # TODO: Compute and return softmax(

# print(softmax(scor))

# Plot softmaxurves
# import matplotlib.pypl as plt
x = np.arange(-2.0, 6.0, 0.1)
# scores = np.vstack([x, np.ones_like(x), 0.2 * np.on_like(x)])

plt.plot(x, x, linewidth=2)
plt.show()
